# %% [markdown]
# #Step 1 : Import the necessary Libraries
# ### import iris dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans

# %% [markdown]
# #Step 2 : Load the iris Dataset

# %%
iris = load_iris()
X = iris.data
Y= iris.target

# %% [markdown]
# #Step 3 : Elbow Method
# Finding the ideal number of groups to divide the data into is a basic stage in any unsupervised algorithm. One of the most common techniques for figuring out this ideal value of k is the elbow approach.

# %%
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4d800eacd43f> in <cell line: 2>()
#       1 inertia = []
#       2 for k in range(1, 11):
# ----> 3     kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0)
#       4     kmeans.fit(X)
#       5     inertia.append(kmeans.inertia_)
#
# NameError: name 'KMeans' is not defined

# %%
inertia = []
#k_range = range(1, 11)
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-830ed5342a48> in <cell line: 3>()
#       2 #k_range = range(1, 11)
#       3 for k in range(1, 11):
# ----> 4     kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0)
#       5     kmeans.fit(X)
#       6     inertia.append(kmeans.inertia_)
#
# NameError: name 'KMeans' is not defined

# %% [markdown]
# #Step 4 : Plot the Elbow graph to find the optimum number of cluster

# %%
#plot the elbow method
plt.figure(figsize=(8,6))
plt.plot(k_range,inertia,marker='o')
plt.title('The Elbow Method(iris Dataset)')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# %% [markdown]
# The plot displays a scatter plot of data points (X[:,0], X[:,1]) with grid lines. It also marks the initial cluster centers (red stars) generated for K-means clustering.

# %% [markdown]
# #Step 5 : Build the Kmeans clustering model
#
#
#
# *   Find the cluster center
# *   Predict the cluster group

# %%
kmeans=KMeans(n_clusters=k,init='k-means++',max_iter=300,n_init=10,random_state=0)
kmeans.fit(X)

cluster_centers = kmeans.cluster_centers_
cluster_centers
# Out:
# array([[4.70454545, 3.12272727, 1.41363636, 0.2       ],
#        [6.52916667, 3.05833333, 5.50833333, 2.1625    ],
#        [6.20769231, 2.85384615, 4.74615385, 1.56410256],
#        [7.475     , 3.125     , 6.3       , 2.05      ],
#        [5.508     , 2.6       , 3.908     , 1.204     ],
#        [5.24285714, 3.66785714, 1.5       , 0.28214286]])

# %% [markdown]
# #Step 6 : Predict the cluster group

# %%
#predict the cluster group for each sample
predicted_labels = kmeans.predict(X)
print(" Predict the cluster labels:/n",predicted_labels)
# Out:
#  Predict the cluster labels:/n [5 0 0 0 5 5 0 5 0 0 5 0 0 0 5 5 5 5 5 5 5 5 0 5 0 0 5 5 5 0 0 5 5 5 0 0 5
#  5 0 5 5 0 0 5 5 0 5 0 5 0 2 2 2 4 2 2 2 4 2 4 4 2 4 2 4 2 2 4 2 4 2 4 2 2
#  2 2 2 2 2 4 4 4 4 2 4 2 2 2 4 4 4 2 4 4 4 4 4 2 4 4 1 2 3 1 1 3 4 3 1 3 1
#  1 1 2 1 1 1 3 3 2 1 2 3 2 1 3 2 2 1 3 3 3 1 2 2 3 1 1 2 1 1 1 2 1 1 1 2 1
#  1 2]

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=predicted_labels,cmap='viridis')
#plt.scatter(cluster_centers[:,0],cluster_centers[:,1],marker='x',c='red',s=200, lable='cluster centers')
plt.xlabel('feature 1')
plt.ylabel('feature 2')
plt.title('K-means Clustering')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #**Well done :)**
